# %%
import os
import sys

import pandas as pd
import torch

# %%
# Add the parent directory of 'src' to sys.path if not already present
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import src.assimilation.assimilator  # noqa: E402
import src.assimilation.test_configs  # noqa: E402, F401

# %%
import matplotlib as mpl

mpl.rcParams["text.usetex"] = True
mpl.rc("text.latex", preamble=r"\usepackage{amsmath}")

# %%
SAVE_ROOT = "../ass_results/assimilate_various_obs_dist"

pickle_cache_path = "./plot_various_obs_dist.pkl"

read_cache = 0

try:
    assert read_cache
    results = pd.read_pickle(pickle_cache_path)
except:  # noqa: E722
    entries = []
    for filename in os.listdir(SAVE_ROOT):
        if filename.endswith(".pt"):
            file_path = os.path.join(SAVE_ROOT, filename)
            print(file_path)
            saved_data = torch.load(file_path, weights_only=False)
            entry = pd.DataFrame(
                {
                    "obs_type": saved_data["obs_type"][0],
                    "method": saved_data["method"],
                    "rand_mask_ratio": saved_data["rand_mask_ratio"],
                    "seed_no": saved_data["seedno"],
                    "rmse": saved_data["rmse"],
                    "step_idx": range(len(saved_data["rmse"])),
                    "time_stride": saved_data["time_stride"],
                    "dist_name": saved_data["dist_name"],
                    "avg_rmse": sum(saved_data["rmse"]) / len(saved_data["rmse"]),
                }
            )
            entries.append(entry)
    results = pd.concat(entries)
    results.to_pickle(pickle_cache_path)
# Out:
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['vor2vel']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['sin3x']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno0_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno1_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seedno2_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist/['arctan3x']_soad_seed
# 7             2  lognormal-1.0  0.132894
# 8             2  lognormal-1.0  0.132894
#
# [1890 rows x 9 columns]

# %%
results.groupby(["time_stride", "obs_type", "dist_name"])["rmse"].mean()
# Out:
# time_stride  obs_type  dist_name
# 1            arctan3x  laplace          0.084545
#                        lognormal-0.1    0.084564
#                        lognormal-0.2    0.084567
#                        lognormal-0.5    0.084601
#                        lognormal-1.0    0.085292
#                        normal           0.084565
#                        uniform          0.084490
#              sin3x     laplace          0.064407
#                        lognormal-0.1    0.064441
#                        lognormal-0.2    0.064440
#                        lognormal-0.5    0.064445
#                        lognormal-1.0    0.065269
#                        normal           0.064443
#                        uniform          0.064414
#              vor2vel   laplace          0.103135
#                        lognormal-0.1    0.103044
#                        lognormal-0.2    0.103050
#                        lognormal-0.5    0.103070
#                        lognormal-1.0    0.103645
#                        normal           0.103038
#                        uniform          0.103141
# 2            arctan3x  laplace          0.119617
#                        lognormal-0.1    0.119585
#                        lognormal-0.2    0.119589
#                        lognormal-0.5    0.119603
#                        lognormal-1.0    0.120257
#                        normal           0.119581
#                        uniform          0.119610
#              sin3x     laplace          0.123326
#                        lognormal-0.1    0.123374
#                        lognormal-0.2    0.123375
#                        lognormal-0.5    0.123372
#                        lognormal-1.0    0.124422
#                        normal           0.123372
#                        uniform          0.123325
#              vor2vel   laplace          0.130508
#                        lognormal-0.1    0.130516
#                        lognormal-0.2    0.130512
#                        lognormal-0.5    0.130505
#                        lognormal-1.0    0.130904
#                        normal           0.130522
#                        uniform          0.130465
# Name: rmse, dtype: float32

# %%
results.groupby(["time_stride", "obs_type", "dist_name"])["rmse"].std()
# Out:
# time_stride  obs_type  dist_name
# 1            arctan3x  laplace          0.004627
#                        lognormal-0.1    0.004667
#                        lognormal-0.2    0.004669
#                        lognormal-0.5    0.004673
#                        lognormal-1.0    0.004793
#                        normal           0.004664
#                        uniform          0.004639
#              sin3x     laplace          0.003628
#                        lognormal-0.1    0.003639
#                        lognormal-0.2    0.003635
#                        lognormal-0.5    0.003635
#                        lognormal-1.0    0.003745
#                        normal           0.003639
#                        uniform          0.003605
#              vor2vel   laplace          0.004903
#                        lognormal-0.1    0.004918
#                        lognormal-0.2    0.004914
#                        lognormal-0.5    0.004901
#                        lognormal-1.0    0.005103
#                        normal           0.004922
#                        uniform          0.004900
# 2            arctan3x  laplace          0.011424
#                        lognormal-0.1    0.011480
#                        lognormal-0.2    0.011485
#                        lognormal-0.5    0.011498
#                        lognormal-1.0    0.011769
#                        normal           0.011475
#                        uniform          0.011410
#              sin3x     laplace          0.012778
#                        lognormal-0.1    0.012721
#                        lognormal-0.2    0.012721
#                        lognormal-0.5    0.012724
#                        lognormal-1.0    0.013123
#                        normal           0.012720
#                        uniform          0.012770
#              vor2vel   laplace          0.011694
#                        lognormal-0.1    0.011688
#                        lognormal-0.2    0.011689
#                        lognormal-0.5    0.011695
#                        lognormal-1.0    0.011899
#                        normal           0.011689
#                        uniform          0.011662
# Name: rmse, dtype: float32
