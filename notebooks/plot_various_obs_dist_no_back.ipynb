# %%
import os
import sys

import pandas as pd
import torch

# %%
# Add the parent directory of 'src' to sys.path if not already present
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import src.assimilation.assimilator  # noqa: E402
import src.assimilation.test_configs  # noqa: E402, F401

# %%
import matplotlib as mpl

mpl.rcParams["text.usetex"] = True
mpl.rc("text.latex", preamble=r"\usepackage{amsmath}")

# %%
SAVE_ROOT = "../ass_results/assimilate_various_obs_dist_no_back"

pickle_cache_path = "./plot_various_obs_dist_no_back.pkl"

read_cache = 0

try:
    assert read_cache
    results = pd.read_pickle(pickle_cache_path)
except:  # noqa: E722
    entries = []
    for filename in os.listdir(SAVE_ROOT):
        if filename.endswith(".pt"):
            file_path = os.path.join(SAVE_ROOT, filename)
            print(file_path)
            saved_data = torch.load(file_path, weights_only=False)
            entry = pd.DataFrame(
                {
                    "obs_type": saved_data["obs_type"][0],
                    "method": saved_data["method"],
                    "rand_mask_ratio": saved_data["rand_mask_ratio"],
                    "seed_no": saved_data["seedno"],
                    "rmse": saved_data["rmse"],
                    "step_idx": range(len(saved_data["rmse"])),
                    "time_stride": saved_data["time_stride"],
                    "dist_name": saved_data["dist_name"],
                    "avg_rmse": sum(saved_data["rmse"]) / len(saved_data["rmse"]),
                }
            )
            entries.append(entry)
    results = pd.concat(entries)
    results.to_pickle(pickle_cache_path)
# Out:
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['arctan3x']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno0_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno1_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno3_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['sin3x']_soad_seedno4_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno0_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno1_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_laplace.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_uniform.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_lognormal-0.2.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_lognormal-0.5.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_lognormal-1.0.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno2_0.25_2_lognormal-0.1.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seedno3_0.25_2_normal.pt
# ../ass_results/assimilate_various_obs_dist_no_back/['vor2vel']_soad_seed
# 6             2  lognormal-1.0  0.756805
# 7             2  lognormal-1.0  0.756805
# 8             2  lognormal-1.0  0.756805
#
# [1890 rows x 9 columns]

# %%
results.groupby(["time_stride", "obs_type", "dist_name"])["rmse"].mean()
# Out:
# time_stride  obs_type  dist_name
# 1            arctan3x  laplace          0.138637
#                        lognormal-0.1    0.138213
#                        lognormal-0.2    0.138236
#                        lognormal-0.5    0.138319
#                        lognormal-1.0    0.142043
#                        normal           0.138191
#                        uniform          0.138434
#              sin3x     laplace          0.144401
#                        lognormal-0.1    0.101446
#                        lognormal-0.2    0.130168
#                        lognormal-0.5    0.120055
#                        lognormal-1.0    0.140685
#                        normal           0.129269
#                        uniform          0.159051
#              vor2vel   laplace          0.118525
#                        lognormal-0.1    0.118502
#                        lognormal-0.2    0.118512
#                        lognormal-0.5    0.118534
#                        lognormal-1.0    0.120064
#                        normal           0.118490
#                        uniform          0.118475
# 2            arctan3x  laplace          0.274970
#                        lognormal-0.1    0.274966
#                        lognormal-0.2    0.274996
#                        lognormal-0.5    0.275054
#                        lognormal-1.0    0.276692
#                        normal           0.274929
#                        uniform          0.275061
#              sin3x     laplace          0.723387
#                        lognormal-0.1    0.719877
#                        lognormal-0.2    0.714500
#                        lognormal-0.5    0.723801
#                        lognormal-1.0    0.729308
#                        normal           0.721426
#                        uniform          0.724088
#              vor2vel   laplace          0.189858
#                        lognormal-0.1    0.189820
#                        lognormal-0.2    0.189826
#                        lognormal-0.5    0.189840
#                        lognormal-1.0    0.191168
#                        normal           0.189814
#                        uniform          0.189859
# Name: rmse, dtype: float32

# %%
results.groupby(["time_stride", "obs_type", "dist_name"])["rmse"].std()
# Out:
# time_stride  obs_type  dist_name
# 1            arctan3x  laplace          0.005311
#                        lognormal-0.1    0.005283
#                        lognormal-0.2    0.005286
#                        lognormal-0.5    0.005304
#                        lognormal-1.0    0.006502
#                        normal           0.005280
#                        uniform          0.005319
#              sin3x     laplace          0.011751
#                        lognormal-0.1    0.035030
#                        lognormal-0.2    0.049982
#                        lognormal-0.5    0.060793
#                        lognormal-1.0    0.016260
#                        normal           0.031738
#                        uniform          0.055866
#              vor2vel   laplace          0.007599
#                        lognormal-0.1    0.007534
#                        lognormal-0.2    0.007538
#                        lognormal-0.5    0.007547
#                        lognormal-1.0    0.007834
#                        normal           0.007531
#                        uniform          0.007601
# 2            arctan3x  laplace          0.010366
#                        lognormal-0.1    0.009733
#                        lognormal-0.2    0.009735
#                        lognormal-0.5    0.009738
#                        lognormal-1.0    0.009209
#                        normal           0.009730
#                        uniform          0.010168
#              sin3x     laplace          0.092773
#                        lognormal-0.1    0.091542
#                        lognormal-0.2    0.083992
#                        lognormal-0.5    0.089756
#                        lognormal-1.0    0.073510
#                        normal           0.091982
#                        uniform          0.094180
#              vor2vel   laplace          0.007951
#                        lognormal-0.1    0.008047
#                        lognormal-0.2    0.008050
#                        lognormal-0.5    0.008053
#                        lognormal-1.0    0.008388
#                        normal           0.008045
#                        uniform          0.007971
# Name: rmse, dtype: float32
